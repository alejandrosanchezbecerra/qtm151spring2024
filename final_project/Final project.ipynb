# %% [markdown]
# # <span style="color:darkblue"> I. Import Libraries and Data </span>

# %% [markdown]
# <font size = "5">
# Key libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <font size = "5">
# Importing Datasets

# %%
drivers = pd.read_csv("data_raw/drivers.csv")
results = pd.read_csv("data_raw/results.csv")

# %% [markdown]
# <font size = "5">
#  Datasets Description

# %%
## Drivers dataset

# Number of rows

len(drivers["driverId"])

# Each row is a driver. There are 857 observations which 
# indicate that there are 857 drivers participating in the race, 
# each with there own specific driverId.


# Variables present

drivers.columns.values

# There are 9 variables within the drivers dataset  driverId', 'driverRef',
# 'number', 'code', 'forename', 'surname', 'dob', 'nationality', 'url'


## Drivers standings

# Number of rows

len(results)

# The number of rows is 25840 which indicates that the number of results from
# the races which can be based on driver Id


# Variables

results.columns.values

# These are the variables that are present in the dataset for results:
# resultId', 'raceId', 'driverId', 'constructorId', 'number',
# 'grid', 'position', 'positionText', 'positionOrder', 'points',
# 'laps', 'time', 'milliseconds', 'fastestLap', 'rank',
# 'fastestLapTime', 'fastestLapSpeed', 'statusId'.
# Out:
# array(['resultId', 'raceId', 'driverId', 'constructorId', 'number',
#        'grid', 'position', 'positionText', 'positionOrder', 'points',
#        'laps', 'time', 'milliseconds', 'fastestLap', 'rank',
#        'fastestLapTime', 'fastestLapSpeed', 'statusId'], dtype=object)

# %% [markdown]
# <font size = "5">
# Merging

# %%
## Create new data set for the fastest times by driver ID

fastest_times = (results.groupby("driverId")
                 ["fastestLapTime"].min())


## Merging data sets drivers and fastest times 

drivers_fastest = pd.merge(drivers,
                         fastest_times,
                         on = "driverId",
                         how = "left")

display(drivers_fastest)

# Merging the two data sets allows us to see the drivers information
# such as nationality, name along with their fastest time. Now we will
# see which nationalities produce the fastest lap times
# Out:
#      driverId        driverRef number code  forename     surname         dob  \
# 0           1         hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1           2         heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2           3          rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3           4           alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4           5       kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ..        ...              ...    ...  ...       ...         ...         ...
# 852       854  mick_schumacher     47  MSC      Mick  Schumacher  1999-03-22
# 853       855             zhou     24  ZHO    Guanyu        Zhou  1999-05-30
# 854       856         de_vries     45  DEV      Nyck    de Vries  1995-02-06
# 855       857          piastri     81  PIA     Oscar     Piastri  2001-04-06
# 856       858         sargeant      2  SAR     Logan    Sargeant  2000-12-31
#
#     nationality                                             url fastestLapTime
# 0       British     http://en.wikipedia.org/wiki/Lewis_Hamilton       1:06.719
# 1        German      http://en.wikipedia.org/wiki/Nick_Heidfeld       1:13.095
# 2        German       http://en.wikipedia.org/wiki/Nico_Rosberg       1:08.491
# 3       Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso       1:08.405
# 4       Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen       1:13.998
# ..          ...                                             ...            ...
# 852      German    http://en.wikipedia.org/wiki/Mick_Schumacher       1:09.394
# 853     Chinese        http://en.wikipedia.org/wiki/Guanyu_Zhou       1:09.380
# 854       Dutch      http://en.wikipedia.org/wiki/Nyck_de_Vries       1:26.624
# 855  Australian      http://en.wikipedia.org/wiki/Oscar_Piastri            NaN
# 856    American     http://en.wikipedia.org/wiki/Logan_Sargeant            NaN
#
# [857 rows x 10 columns]

# %% [markdown]
# <font size = "5">
# Querry

# %%
## Grouping by nationality and seeing which ones had the fast times
 
#merge driver based on nationality and calculate average placement
rank_driver = pd.merge(drivers,
                       results,
                       on = "driverId",
                       how = "left")

rank_driver['rank'] = pd.to_numeric(rank_driver['rank'], errors= 'coerce')
rank_driver['points'] = pd.to_numeric(rank_driver['points'], errors= 'coerce')
rank_driver['position'] = pd.to_numeric(rank_driver['position'], errors= 'coerce')

nat_avg = (rank_driver.groupby("nationality")
          .agg(mean_rank = ('rank','mean'),
                 mean_points = ('points','mean'),
                 mean_position = ('position','mean')))

nat_avg = nat_avg.sort_values(by = 'mean_points', ascending= False)


display(nat_avg)
# Out:
#                    mean_rank  mean_points  mean_position
# nationality
# Monegasque          7.320388     6.477273       6.309278
# Dutch               8.966245     4.192708       8.283217
# Finnish             8.006579     3.817350       6.903585
# Spanish             8.940375     3.535888       8.118674
# Australian          8.862408     3.445189       7.294444
# German              9.629630     3.333263       7.537800
# Mexican             9.834459     3.035545       8.895765
# Polish             10.530612     2.767677       9.411765
# Thai                9.915254     2.679487       9.396825
# Colombian           6.023810     2.456000       4.805970
# British             9.015593     2.391725       6.823183
# Argentine                NaN     1.873780       5.379808
# Brazilian          10.342441     1.752688       7.533220
# Austrian           14.000000     1.435507       6.602667
# New Zealander      12.960000     1.367424       6.246753
# South African            NaN     1.342857       6.477876
# Russian            12.009434     1.253521      12.368421
# Canadian           12.527778     1.205752       9.875000
# French             12.578856     1.152906       8.166866
# Danish             12.161972     1.016949      11.992366
# American           15.066667     0.780297       8.477204
# Swedish            14.989691     0.776471       8.649254
# Swiss              13.039216     0.701613       8.068966
# Belgian            14.548387     0.656514       8.690722
# Venezuelan         11.812500     0.641667      12.567568
# Italian            12.864198     0.597326       8.589005
# Japanese           13.180328     0.398425      11.196923
# Rhodesian                NaN     0.333333       9.125000
# Chinese            11.818182     0.272727      12.882353
# Irish                    NaN     0.173913       9.294118
# Portuguese         16.416667     0.091954      12.265306
# Indian             18.913793     0.084746      17.190476
# Chilean                  NaN     0.081081      10.500000
# Hungarian          18.833333     0.050000      13.500000
# Malaysian                NaN     0.000000      12.166667
# Indonesian         16.083333     0.000000      18.222222
# American-Italian         NaN     0.000000            NaN
# Liechtensteiner          NaN     0.000000      11.500000
# East German              NaN     0.000000      13.666667
# Czech                    NaN     0.000000      13.000000
# Argentine-Italian        NaN     0.000000       9.000000
# Uruguayan                NaN     0.000000       7.666667
