# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 2 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your answer here

print("Martinez Jean Claude")
# Out:
# Martinez Jean Claude

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
# Write your answer here:

print("I will abide by the honor code!")
# Out:
# I will abide by the honor code!

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pyplot", <br>
# "pandas", "statsmodels.api" and "statsmodels.formula.api"

# %%
# Write your answer here

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# <font size = "5">
#
# Read the dataset "data_quiz/fifa23_players_basic.csv"
#
# - It's a dataset on professional soccer players
# - Rows correspond to players (18,539)
# - Columns contain attributes of players (32)
# - Try to view the dataset before starting <br>
# to get a sense of its content

# %%
# Write your own code

fifa = pd.read_csv("data_quiz/fifa23_players_basic.csv")
display(fifa)
# Out:
#        Unnamed: 0        Known As           Full Name  Overall  Potential  \
# 0               0        L. Messi        Lionel Messi       91         91
# 1               1      K. Benzema       Karim Benzema       91         91
# 2               2  R. Lewandowski  Robert Lewandowski       91         91
# 3               3    K. De Bruyne     Kevin De Bruyne       91         91
# 4               4       K. Mbappé       Kylian Mbappé       91         95
# ...           ...             ...                 ...      ...        ...
# 18534       18534      D. Collins      Darren Collins       47         56
# 18535       18535    Yang Dejiang        Dejiang Yang       47         57
# 18536       18536       L. Mullan         Liam Mullan       47         67
# 18537       18537    D. McCallion    Daithí McCallion       47         61
# 18538       18538        N. Rabha         Nabin Rabha       47         50
#
#        Value(in Euro) Positions Played Best Position          Nationality  \
# 0            54000000               RW           CAM            Argentina
# 1            64000000            CF,ST            CF               France
# 2            84000000               ST            ST               Poland
# 3           107500000           CM,CAM            CM              Belgium
# 4           190500000            ST,LW            ST               France
# ...               ...              ...           ...                  ...
# 18534          110000            ST,RM           CAM  Republic of Ireland
# 18535           90000              CDM           CDM             China PR
# 18536          130000               CM            RM     Northern Ireland
# 18537          100000               CB            CB  Republic of Ireland
# 18538           60000               LB            LB                India
#
#                                              Image Link  ...  Preferred Foot  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png  ...            Left
# 1      https://cdn.sofifa.net/players/165/153/23_60.png  ...           Right
# 2      https://cdn.sofifa.net/players/188/545/23_60.png  ...           Right
# 3      https://cdn.sofifa.net/players/192/985/23_60.png  ...           Right
# 4      https://cdn.sofifa.net/players/231/747/23_60.png  ...           Right
# ...                                                 ...  ...             ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png  ...           Right
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png  ...           Right
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png  ...           Right
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png  ...           Right
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png  ...            Left
#
#        Weak Foot Rating  Skill Moves  International Reputation  \
# 0                     4            4                         5
# 1                     4            4                         4
# 2                     4            4                         5
# 3                     5            4                         4
# 4                     4            5                         4
# ...                 ...          ...                       ...
# 18534                 3            2                         1
# 18535                 3            2                         1
# 18536                 3            2                         1
# 18537                 3            2                         1
# 18538                 3            2                         1
#
#        National Team Name             National Team Image Link  \
# 0               Argentina  https://cdn.sofifa.net/flags/ar.png
# 1                  France  https://cdn.sofifa.net/flags/fr.png
# 2                  Poland  https://cdn.sofifa.net/flags/pl.png
# 3                 Belgium  https://cdn.sofifa.net/flags/be.png
# 4                  France  https://cdn.sofifa.net/flags/fr.png
# ...                   ...                                  ...
# 18534                   -                                    -
# 18535                   -                                    -
# 18536                   -                                    -
# 18537                   -                                    -
# 18538                   -                                    -
#
#        National Team Position  National Team Jersey Number  \
# 0                          RW                           10
# 1                          ST                           19
# 2                          ST                            9
# 3                          RF                            7
# 4                          ST                           10
# ...                       ...                          ...
# 18534                       -                            -
# 18535                       -                            -
# 18536                       -                            -
# 18537                       -                            -
# 18538                       -                            -
#
#       Attacking Work Rate Defensive Work Rate
# 0                     Low                 Low
# 1                  Medium              Medium
# 2                    High              Medium
# 3                    High                High
# 4                    High                 Low
# ...                   ...                 ...
# 18534              Medium              Medium
# 18535              Medium              Medium
# 18536                High              Medium
# 18537              Medium              Medium
# 18538              Medium              Medium
#
# [18539 rows x 33 columns]

# %% [markdown]
# <font size = "5">
#
# (a) Use queries + global variables
#
# <font size = "3">
#
# - Subset the players whose value of the column "On Loan" is "YES" <br>
# and store it in a new dataset
# - How many players are on loan?
#
# HINT: Remember that there is a special syntax for <br>
# when the column names have spaces (see Lecture 10) <br>
# and when the value is a string. <br>
# Reference the column as ``` `On Loan` ``` inside .query()

# %%
# Write your own code

loan = "YES"

players_onloan = fifa.query("`On Loan` == @loan ")

print(" The number players on loan is " + str(len(players_onloan)))
# Out:
#  The number players on loan is 1229

# %% [markdown]
# <font size = "5">
#
# (b) Create a function and apply it to a column <br>
#
# <font size = "3">
#
# Step 1:
# - Define a function with a parameter "Overall"
# - If "Overall > 90", classification = "Top Performer"
# - If "Overall <= 90", classification = "Non Top-Performer"
# - The function returns "classification"
#
# Step 2:
# - Extract the column "Overall" in the dataset <br>
# (be carefeful to write the "O" capitalized)
# - Create a new variable called "player_classification" <br>
# to assign each player to the correct classification
#
# HINT: Use the ".apply()" function

# %%
# Write your own code

def my_fun(overall):
    if overall > 90:
        classification = "Top Performer"
        return classification
    else:
        classification = "Non Top-Performer"
        return classification

fifa_overall = fifa["Overall"]
player_classification = fifa_overall.apply(my_fun)
player_classification
# Out:
# 0            Top Performer
# 1            Top Performer
# 2            Top Performer
# 3            Top Performer
# 4            Top Performer
#                ...
# 18534    Non Top-Performer
# 18535    Non Top-Performer
# 18536    Non Top-Performer
# 18537    Non Top-Performer
# 18538    Non Top-Performer
# Name: Overall, Length: 18539, dtype: object

# %% [markdown]
# <font size = "5">
#
# (c) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# The varable "Joined On" shows the date in which each player joined FIFA
# - Use ".sort_values()" to order the "Joined On" column <br>
# from earlier data to later date
# - Get a subset with the 6 players in the dataset <br>
# who joined FIFA earliest
# - From this subset, display the year in which they joined <br>
# by displaying the column "Joined On"

# %%
# Write your own code

fifa_unique = pd.unique(fifa["Joined On"])

display(fifa_unique)

fifa_sort = fifa.sort_values("Joined On", ascending= True)

earliest_players = fifa_sort.iloc[0:6, :]

display(earliest_players)

display(earliest_players["Joined On"])
# Out:
# array([2021, 2009, 2022, 2015, 2018, 2017, 2011, 2010, 2014, 2016, 2020,
#        2019, 2013, 2012, 2008, 2007, 2006, 2004, 2005, 2002, 2003])
#        Unnamed: 0       Known As        Full Name  Overall  Potential  \
# 8586         8586   D. Lewington   Dean Lewington       66         66
# 10877       10877    P. Karlsson     Per Karlsson       64         64
# 4324         4324       I. Khune  Itumeleng Khune       70         70
# 11056       11056    Cai Huikang      Huikang Cai       64         64
# 10360       10360   L. Stevenson  Lewis Stevenson       65         65
# 11768       11768  Wang Shenchao    Shenchao Wang       64         64
#
#        Value(in Euro) Positions Played Best Position   Nationality  \
# 8586           150000               CB           CDM       England
# 10877          100000               CB            CB        Sweden
# 4324           180000               GK            GK  South Africa
# 11056          400000           CDM,CM            CB      China PR
# 10360          250000               LB            LB      Scotland
# 11768          275000            CB,RM            CB      China PR
#
#                                              Image Link  ...  Preferred Foot  \
# 8586   https://cdn.sofifa.net/players/138/830/23_60.png  ...            Left
# 10877  https://cdn.sofifa.net/players/176/717/23_60.png  ...           Right
# 4324   https://cdn.sofifa.net/players/165/247/23_60.png  ...           Right
# 11056  https://cdn.sofifa.net/players/224/608/23_60.png  ...           Right
# 10360  https://cdn.sofifa.net/players/175/316/23_60.png  ...            Left
# 11768  https://cdn.sofifa.net/players/224/604/23_60.png  ...           Right
#
#        Weak Foot Rating  Skill Moves  International Reputation  \
# 8586                  3            2                         1
# 10877                 3            2                         1
# 4324                  5            1                         2
# 11056                 3            3                         1
# 10360                 3            2                         1
# 11768                 4            3                         1
#
#        National Team Name                 National Team Image Link  \
# 8586                    -  https://cdn.sofifa.net/flags/gb-eng.png
# 10877                   -      https://cdn.sofifa.net/flags/se.png
# 4324                    -      https://cdn.sofifa.net/flags/za.png
# 11056                   -                                        -
# 10360                   -  https://cdn.sofifa.net/flags/gb-sct.png
# 11768            China PR                                        -
#
#        National Team Position  National Team Jersey Number  \
# 8586                        -                            -
# 10877                       -                            -
# 4324                        -                            -
# 11056                       -                            -
# 10360                       -                            -
# 11768                      RB                            4
#
#       Attacking Work Rate Defensive Work Rate
# 8586                 High              Medium
# 10877                 Low                High
# 4324               Medium              Medium
# 11056                 Low                High
# 10360                High                High
# 11768                High                High
#
# [6 rows x 33 columns]
# 8586     2002
# 10877    2003
# 4324     2004
# 11056    2005
# 10360    2005
# 11768    2005
# Name: Joined On, dtype: int64

# %% [markdown]
# <font size = "5">
#
# (d) Regression function
#
# <font size = "3">
#
# - Run a regression of "Potential" (left-hand side) on "Age" (right-hand side)
# - What are the values of the coefficients?
#
# [HINT: Use the commands ```smf.ols()``` and ```.fit()``` and ```.params``` <br>
# from Lecture 11 ]

# %%
# Write your own code


reg = smf.ols(formula = 'Potential ~ Age', data= fifa)
regresults = reg.fit()

coef = regresults.params

display(coef)

print(" The values of the coefficients are B1 = -0.346103 and B0 = 79.752454 " )
# Out:
# Intercept    79.752454
# Age          -0.346103
# dtype: float64
#  The values of the coefficients are B1 = -0.346103 and B0 = 79.752454

# %% [markdown]
# <font size = "5">
#
# (e) Split a dataset into subsets
#
# <font size = "3">
#
# - Store the total number of rows of the dataset in a variable called ```n``` <br>
# - Create a new variable called ```random_var``` drawn from a <br>
# uniform distribution between 0 and 1 with size ```n```
# - Use .query() to subset all observations with ```random_var <0.5```.<br>
# store it in a new dataset called "data0"
# - Use .query() to subset all observations with ```random_var >= 0.5```.<br>
# store it in a new dataset called "data1"
#
# [HINT: See Lecture 2 for how to generate a uniform random variable]

# %%
# Write your own code

n = len(fifa)
random_var = np.random.uniform(low = 0, high = 1, size = n)

data0 = fifa.query("@random_var < 0.5")
data1 = fifa.query("@random_var >= 0.5")

display(data0)
display(data1)
# Out:
#        Unnamed: 0        Known As           Full Name  Overall  Potential  \
# 0               0        L. Messi        Lionel Messi       91         91
# 1               1      K. Benzema       Karim Benzema       91         91
# 2               2  R. Lewandowski  Robert Lewandowski       91         91
# 3               3    K. De Bruyne     Kevin De Bruyne       91         91
# 5               5        M. Salah       Mohamed Salah       90         90
# ...           ...             ...                 ...      ...        ...
# 18526       18526    Chen Chunxin        Chunxin Chen       48         52
# 18527       18527     Liu Junxian         Junxian Liu       48         58
# 18528       18528       Zhang Yue           Yue Zhang       48         56
# 18533       18533       Pi Ziyang           Ziyang Pi       47         60
# 18535       18535    Yang Dejiang        Dejiang Yang       47         57
#
#        Value(in Euro) Positions Played Best Position Nationality  \
# 0            54000000               RW           CAM   Argentina
# 1            64000000            CF,ST            CF      France
# 2            84000000               ST            ST      Poland
# 3           107500000           CM,CAM            CM     Belgium
# 5           115500000               RW            RW       Egypt
# ...               ...              ...           ...         ...
# 18526           70000               CM            RM    China PR
# 18527          110000               ST            ST    China PR
# 18528          110000               RM            LM    China PR
# 18533          110000               CM           CAM    China PR
# 18535           90000              CDM           CDM    China PR
#
#                                              Image Link  ...  Preferred Foot  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png  ...            Left
# 1      https://cdn.sofifa.net/players/165/153/23_60.png  ...           Right
# 2      https://cdn.sofifa.net/players/188/545/23_60.png  ...           Right
# 3      https://cdn.sofifa.net/players/192/985/23_60.png  ...           Right
# 5      https://cdn.sofifa.net/players/209/331/23_60.png  ...            Left
# ...                                                 ...  ...             ...
# 18526  https://cdn.sofifa.net/players/255/597/23_60.png  ...           Right
# 18527  https://cdn.sofifa.net/players/264/056/23_60.png  ...           Right
# 18528  https://cdn.sofifa.net/players/268/922/23_60.png  ...            Left
# 18533  https://cdn.sofifa.net/players/269/066/23_60.png  ...           Right
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png  ...           Right
#
#        Weak Foot Rating  Skill Moves  International Reputation  \
# 0                     4            4                         5
# 1                     4            4                         4
# 2                     4            4                         5
# 3                     5            4                         4
# 5                     3            4                         4
# ...                 ...          ...                       ...
# 18526                 3            2                         1
# 18527                 3            2                         1
# 18528                 2            2                         1
# 18533                 3            2                         1
# 18535                 3            2                         1
#
#        National Team Name             National Team Image Link  \
# 0               Argentina  https://cdn.sofifa.net/flags/ar.png
# 1                  France  https://cdn.sofifa.net/flags/fr.png
# 2                  Poland  https://cdn.sofifa.net/flags/pl.png
# 3                 Belgium  https://cdn.sofifa.net/flags/be.png
# 5                       -                                    -
# ...                   ...                                  ...
# 18526                   -                                    -
# 18527                   -                                    -
# 18528                   -                                    -
# 18533                   -                                    -
# 18535                   -                                    -
#
#        National Team Position  National Team Jersey Number  \
# 0                          RW                           10
# 1                          ST                           19
# 2                          ST                            9
# 3                          RF                            7
# 5                           -                            -
# ...                       ...                          ...
# 18526                       -                            -
# 18527                       -                            -
# 18528                       -                            -
# 18533                       -                            -
# 18535                       -                            -
#
#       Attacking Work Rate Defensive Work Rate
# 0                     Low                 Low
# 1                  Medium              Medium
# 2                    High              Medium
# 3                    High                High
# 5                    High              Medium
# ...                   ...                 ...
# 18526              Medium              Medium
# 18527              Medium              Medium
# 18528              Medium              Medium
# 18533              Medium              Medium
# 18535              Medium              Medium
#
# [9209 rows x 33 columns]
#        Unnamed: 0      Known As          Full Name  Overall  Potential  \
# 4               4     K. Mbappé      Kylian Mbappé       91         95
# 6               6   T. Courtois   Thibaut Courtois       90         91
# 7               7      M. Neuer       Manuel Neuer       90         90
# 9               9   V. van Dijk    Virgil van Dijk       90         90
# 10             10       H. Kane         Harry Kane       89         89
# ...           ...           ...                ...      ...        ...
# 18532       18532      H. Singh  Harmanpreet Singh       48         56
# 18534       18534    D. Collins     Darren Collins       47         56
# 18536       18536     L. Mullan        Liam Mullan       47         67
# 18537       18537  D. McCallion   Daithí McCallion       47         61
# 18538       18538      N. Rabha        Nabin Rabha       47         50
#
#        Value(in Euro) Positions Played Best Position          Nationality  \
# 4           190500000            ST,LW            ST               France
# 6            90000000               GK            GK              Belgium
# 7            13500000               GK            GK              Germany
# 9            98000000               CB            CB          Netherlands
# 10          105500000               ST            ST              England
# ...               ...              ...           ...                  ...
# 18532          100000               ST            ST                India
# 18534          110000            ST,RM           CAM  Republic of Ireland
# 18536          130000               CM            RM     Northern Ireland
# 18537          100000               CB            CB  Republic of Ireland
# 18538           60000               LB            LB                India
#
#                                              Image Link  ...  Preferred Foot  \
# 4      https://cdn.sofifa.net/players/231/747/23_60.png  ...           Right
# 6      https://cdn.sofifa.net/players/192/119/23_60.png  ...            Left
# 7      https://cdn.sofifa.net/players/167/495/23_60.png  ...           Right
# 9      https://cdn.sofifa.net/players/203/376/23_60.png  ...           Right
# 10     https://cdn.sofifa.net/players/202/126/23_60.png  ...           Right
# ...                                                 ...  ...             ...
# 18532  https://cdn.sofifa.net/players/259/745/23_60.png  ...           Right
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png  ...           Right
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png  ...           Right
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png  ...           Right
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png  ...            Left
#
#        Weak Foot Rating  Skill Moves  International Reputation  \
# 4                     4            5                         4
# 6                     3            1                         4
# 7                     4            1                         5
# 9                     3            2                         4
# 10                    5            3                         4
# ...                 ...          ...                       ...
# 18532                 2            2                         1
# 18534                 3            2                         1
# 18536                 3            2                         1
# 18537                 3            2                         1
# 18538                 3            2                         1
#
#        National Team Name                 National Team Image Link  \
# 4                  France      https://cdn.sofifa.net/flags/fr.png
# 6                 Belgium      https://cdn.sofifa.net/flags/be.png
# 7                 Germany      https://cdn.sofifa.net/flags/de.png
# 9             Netherlands      https://cdn.sofifa.net/flags/nl.png
# 10                England  https://cdn.sofifa.net/flags/gb-eng.png
# ...                   ...                                      ...
# 18532                   -                                        -
# 18534                   -                                        -
# 18536                   -                                        -
# 18537                   -                                        -
# 18538                   -                                        -
#
#        National Team Position  National Team Jersey Number  \
# 4                          ST                           10
# 6                          GK                            1
# 7                          GK                            1
# 9                          CB                            4
# 10                         ST                            9
# ...                       ...                          ...
# 18532                       -                            -
# 18534                       -                            -
# 18536                       -                            -
# 18537                       -                            -
# 18538                       -                            -
#
#       Attacking Work Rate Defensive Work Rate
# 4                    High                 Low
# 6                  Medium              Medium
# 7                  Medium              Medium
# 9                  Medium                High
# 10                   High                High
# ...                   ...                 ...
# 18532              Medium                 Low
# 18534              Medium              Medium
# 18536                High              Medium
# 18537              Medium              Medium
# 18538              Medium              Medium
#
# [9330 rows x 33 columns]

# %% [markdown]
# <font size = "5">
#
# (f) Create two overlapping histogram plots
#
# <font size = "3">
#
# - This question requires the two datasets you created in (e)
# - Display the distribution of "Age" for "data0" and "data1" using <br>
# ```plt.hist()```
# - You will need to label the axes, and the title
# - To get full points, plot the histograms with the option  ```alpha = 0.5```, e.g. <br>
#  ``` plt.hist(x = ..., alpha = 0.5) ``` <br>
#  Make sure to substitute the corresponding "x" vector instead of ```...``` <br>
# (The alpha option sets the transparency of the histogram )
#
# Note: The goal of this question is to illustrate that random <br>
# assignment produces very similar distributions between two groups

# %%
# Write your own code


plt.hist(x = data0["Age"], alpha = 0.5, color = "red")
plt.hist(x = data1["Age"], alpha = 0.5, color = "blue")
plt.ylabel("Frequency")
plt.xlabel("Age")
plt.title("Distribution of Age")
plt.legend(labels = ["Data0", "Data1"])
