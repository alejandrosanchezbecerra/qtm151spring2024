# %% [markdown]
# # <span style="color:darkblue"> Lecture 13: Quiz 2 </span>
#
# <font size = "5">
#
# Quiz will take 50 minutes of class time <br>
#
# Covering modules 1, 2, and 3
#
# Exercises posted on Canvas
